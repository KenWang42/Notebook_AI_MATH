# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

data = pd.read_csv('ex2data2.txt')
data.columns = ['X','Y','R']

data1 = data[data.R == 1]
plt.plot(data1['X'], data1['Y'], 'ro')

data0 = data[data.R == 0]
plt.plot(data0['X'], data0['Y'], 'bo')
